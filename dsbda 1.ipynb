# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as se

# %%
df=pd.read_csv("weatherAUS.csv")

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %%
df.head(5)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
df.tail(5)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 142188       NaN           E           31.0        ESE  ...        27.0
# 142189       NaN           E           31.0         SE  ...        24.0
# 142190       NaN         NNW           22.0         SE  ...        21.0
# 142191       NaN           N           37.0         SE  ...        24.0
# 142192       NaN          SE           28.0        SSE  ...        24.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=142193, step=1)

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df.shape
# Out:
# (142193, 24)

# %%
df.columns.values
# Out:
# array(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall',
#        'Evaporation', 'Sunshine', 'WindGustDir', 'WindGustSpeed',
#        'WindDir9am', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm',
#        'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'RainToday',
#        'RISK_MM', 'RainTomorrow'], dtype=object)

# %%
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  141556.000000  141871.000000  140787.000000  81350.000000
# mean       12.186400      23.226784       2.349974      5.469824
# std         6.403283       7.117618       8.465173      4.188537
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.800000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  74377.000000  132923.000000  140845.000000  139563.000000
# mean       7.624853      39.984292      14.001988      18.637576
# std        3.781525      13.588801       8.893337       8.803345
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
df.describe(include="all")
# Out:
#               Date  Location        MinTemp        MaxTemp       Rainfall  \
# count       142193    142193  141556.000000  141871.000000  140787.000000
# unique        3436        49            NaN            NaN            NaN
# top     2013-12-01  Canberra            NaN            NaN            NaN
# freq            49      3418            NaN            NaN            NaN
# mean           NaN       NaN      12.186400      23.226784       2.349974
# std            NaN       NaN       6.403283       7.117618       8.465173
# min            NaN       NaN      -8.500000      -4.800000       0.000000
# 25%            NaN       NaN       7.600000      17.900000       0.000000
# 50%            NaN       NaN      12.000000      22.600000       0.000000
# 75%            NaN       NaN      16.800000      28.200000       0.800000
# max            NaN       NaN      33.900000      48.100000     371.000000
#
#          Evaporation      Sunshine WindGustDir  WindGustSpeed WindDir9am  ...  \
# ...

# %%
df.head(2)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
#
#    RainTomorrow
# 0            No
# 1            No
#
# [2 rows x 24 columns]

# %%
df.iloc[:10,:5]
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall
# 0  2008-12-01   Albury     13.4     22.9       0.6
# 1  2008-12-02   Albury      7.4     25.1       0.0
# 2  2008-12-03   Albury     12.9     25.7       0.0
# 3  2008-12-04   Albury      9.2     28.0       0.0
# 4  2008-12-05   Albury     17.5     32.3       1.0
# 5  2008-12-06   Albury     14.6     29.7       0.2
# 6  2008-12-07   Albury     14.3     25.0       0.0
# 7  2008-12-08   Albury      7.7     26.7       0.0
# 8  2008-12-09   Albury      9.7     31.9       0.0
# 9  2008-12-10   Albury     13.1     30.1       1.4

# %%
df[0:3]
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
# 2       1008.7       NaN       2.0     21.0     23.2         No      0.0
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
#
# ...

# %%
df.head(2)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
#
#    RainTomorrow
# 0            No
# 1            No
#
# [2 rows x 24 columns]

# %%
df.Rainfall.sort_index(ascending=False)
# Out:
# 142192    0.0
# 142191    0.0
# 142190    0.0
# 142189    0.0
# 142188    0.0
#          ...
# 4         1.0
# 3         0.0
# 2         0.0
# 1         0.0
# 0         0.6
# Name: Rainfall, Length: 142193, dtype: float64

# %%
df.sort_values(by="MinTemp")
# Out:
#               Date     Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 50958   2009-06-11  MountGinini     -8.5      0.6       1.0          NaN
# 52983   2015-08-04  MountGinini     -8.2     -0.8       0.0          NaN
# 48686   2011-07-29  Tuggeranong     -8.2     15.2       0.0          NaN
# 51276   2010-06-29  MountGinini     -8.0      2.1       NaN          NaN
# 45682   2011-07-29     Canberra     -8.0     15.1       0.2          2.6
# ...            ...          ...      ...      ...       ...          ...
# 140614  2017-04-27    Katherine      NaN     35.0       0.0          NaN
# 140646  2017-05-29    Katherine      NaN     33.5       0.0          NaN
# 141031  2014-02-25        Uluru      NaN     27.2       NaN          NaN
# 141040  2014-03-08        Uluru      NaN     36.4       NaN          NaN
# 141072  2014-05-19        Uluru      NaN     28.4       NaN          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %%
df["Location"]
# Out:
# 0         Albury
# 1         Albury
# 2         Albury
# 3         Albury
# 4         Albury
#            ...
# 142188     Uluru
# 142189     Uluru
# 142190     Uluru
# 142191     Uluru
# 142192     Uluru
# Name: Location, Length: 142193, dtype: object

# %%
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
# 3          NE           24.0         SE  ...        16.0       1017.6
# 4           W           41.0        ENE  ...        33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# ...

# %%
df.iloc[:,[2,1]]
# Out:
#         MinTemp Location
# 0          13.4   Albury
# 1           7.4   Albury
# 2          12.9   Albury
# 3           9.2   Albury
# 4          17.5   Albury
# ...         ...      ...
# 142188      3.5    Uluru
# 142189      2.8    Uluru
# 142190      3.6    Uluru
# 142191      5.4    Uluru
# 142192      7.8    Uluru
#
# [142193 rows x 2 columns]

# %%
df.loc[10:20,["MinTemp","Location"]]
# Out:
#     MinTemp Location
# 10     13.4   Albury
# 11     15.9   Albury
# 12     15.9   Albury
# 13     12.6   Albury
# 14      9.8   Albury
# 15     14.1   Albury
# 16     13.5   Albury
# 17     11.2   Albury
# 18      9.8   Albury
# 19     11.5   Albury
# 20     17.1   Albury

# %%
df.iloc[:3]
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
# 2       1008.7       NaN       2.0     21.0     23.2         No      0.0
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
#
# ...

# %%
df.iloc[:3,:]
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 0           W           44.0          W  ...        22.0       1007.7
# 1         WNW           44.0        NNW  ...        25.0       1010.6
# 2         WSW           46.0          W  ...        30.0       1007.6
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 0       1007.1       8.0       NaN     16.9     21.8         No      0.0
# 1       1007.8       NaN       NaN     17.2     24.3         No      0.0
# 2       1008.7       NaN       2.0     21.0     23.2         No      0.0
#
#    RainTomorrow
# 0            No
# 1            No
# 2            No
#
# ...

# %%
df.iloc[:,:9]
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed
# 0            NaN           W           44.0
# 1            NaN         WNW           44.0
# ...

# %%
df.isnull()
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       False     False    False    False     False         True      True
# 1       False     False    False    False     False         True      True
# 2       False     False    False    False     False         True      True
# 3       False     False    False    False     False         True      True
# 4       False     False    False    False     False         True      True
# ...       ...       ...      ...      ...       ...          ...       ...
# 142188  False     False    False    False     False         True      True
# 142189  False     False    False    False     False         True      True
# 142190  False     False    False    False     False         True      True
# 142191  False     False    False    False     False         True      True
# 142192  False     False    False    False     False         True      True
#
# ...

# %%
df.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday         1406
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# Date                 0
# Location             0
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustDir       9330
# WindGustSpeed     9270
# WindDir9am       10013
# WindDir3pm        3778
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# RainToday         1406
# RISK_MM              0
# RainTomorrow         0
# dtype: int64

# %%
df.notnull()
# Out:
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       True      True     True     True      True        False     False
# 1       True      True     True     True      True        False     False
# 2       True      True     True     True      True        False     False
# 3       True      True     True     True      True        False     False
# 4       True      True     True     True      True        False     False
# ...      ...       ...      ...      ...       ...          ...       ...
# 142188  True      True     True     True      True        False     False
# 142189  True      True     True     True      True        False     False
# 142190  True      True     True     True      True        False     False
# 142191  True      True     True     True      True        False     False
# 142192  True      True     True     True      True        False     False
#
#         WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity3pm  Pressure9am  \
# ...

# %%
df.notnull().sum()
# Out:
# Date             142193
# Location         142193
# MinTemp          141556
# MaxTemp          141871
# Rainfall         140787
# Evaporation       81350
# Sunshine          74377
# WindGustDir      132863
# WindGustSpeed    132923
# WindDir9am       132180
# WindDir3pm       138415
# WindSpeed9am     140845
# WindSpeed3pm     139563
# Humidity9am      140419
# Humidity3pm      138583
# Pressure9am      128179
# Pressure3pm      128212
# Cloud9am          88536
# Cloud3pm          85099
# Temp9am          141289
# Temp3pm          139467
# RainToday        140787
# RISK_MM          142193
# RainTomorrow     142193
# dtype: int64

# %%
df.notnull().sum(axis=1)
# Out:
# 0         21
# 1         20
# 2         21
# 3         20
# 4         22
#           ..
# 142188    20
# 142189    20
# 142190    20
# 142191    20
# 142192    22
# Length: 142193, dtype: int64

# %%
df.size
# Out:
# 3412632

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# Date              object
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RISK_MM          float64
# RainTomorrow      object
# dtype: object

# %%
df['WindGustSpeed']=df['WindGustSpeed'].astype(float)

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...

# %%
df["Location"].replace({"Albury":0,"Uluru":1},inplace=True)
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_24044\2043230465.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Location"].replace({"Albury":0,"Uluru":1},inplace=True)

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01        0     13.4     22.9       0.6          NaN
# 1       2008-12-02        0      7.4     25.1       0.0          NaN
# 2       2008-12-03        0     12.9     25.7       0.0          NaN
# 3       2008-12-04        0      9.2     28.0       0.0          NaN
# 4       2008-12-05        0     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20        1      3.5     21.8       0.0          NaN
# 142189  2017-06-21        1      2.8     23.4       0.0          NaN
# 142190  2017-06-22        1      3.6     25.3       0.0          NaN
# 142191  2017-06-23        1      5.4     26.9       0.0          NaN
# 142192  2017-06-24        1      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# ...
